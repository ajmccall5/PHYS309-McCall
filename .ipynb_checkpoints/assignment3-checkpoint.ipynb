# %% [markdown]
# # Assignment 3

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import constants

plt.rcParams.update({"font.size":16, "axes.labelsize":16, "font.family":"sans-serif", 
                     "font.sans-serif":"Arial"})

# %% [markdown]
# <ol>
#     <li>Recall the velocity addition example from class: Frank is on a space station, Mary is in a spacecraft moving away from the space station in the +x direction, and she is firing a proton gun at asteroids that are in the spacecraft's path.
#         <ol>
#             <li>Assume the protons leave the proton gun with speed 0.99c in the +x direction. Plot the proton speed measured by <em>Frank</em> as a function of spacecraft speed relative to the space station.</li>
#             <li>Now suppose the protons leave the gun in a "cone" shape rather than straight along the +x axis, so that their velocity vectors have y and z components. The angle of the proton code is $15^{\circ}$, and their launch speed is still 0.99c. Plot Frank's measurement of the y-component of the proton velocity at the edge of the cone, as a function of spacecraft speed.</li>
#         </ol>
#     </li>
# </ol>

# %%
#1.A.

c=constants.c
v = np.linspace(0.01, c,num=250,endpoint=False)#Speed of the spacecraft relative to space station
up=0.99*c#Speed of the proton shot relative to spacecraft
B=v/c
g=1/((1-B**2)**0.5)
u=g*((up+v)/(1+up*v/(c**2)))#Speed of the proton shot relative to space station
plt.semilogy(v,u)

#plt.plot(v/c,u/c)
plt.xlabel('Speed of Spacecraft [m/s]')
plt.ylabel('Speed of Proton to Space Station [m/s]');
plt.show()

#1.B.
Pspeed=0.99*c
LAdeg=15#Proton Launch Angle (deg)
LArad=LAdeg*(np.pi/180)#Proton Launch Angle (rad)
uyp=np.sin(LArad)*Pspeed#Proton y-velocity relative to spacecraft
uxp=np.cos(LArad)*Pspeed#Proton x-velocity relative to spacecraft
uy=uyp/(g*(1+up*v/(c**2)))#Proton y-velocity relative to space station
plt.plot(v,uy)
plt.xlabel('Speed of Spacecraft [m/s]')
plt.ylabel('Speed of y-component of Proton [m/s]');
plt.show()

# %% [markdown]
# <ol start=2>
#     <li>Make a 2-d plot of spacetime with $x$ on the horizontal axis and $ct$ on the vertical axis.
#     <ol>
#         <li>Imagine two flashbulbs positioned in the Earth's approximate rest frame with locations $x = 0$ km and $x = 300000$ km (slightly less than the moon's distance from Earth). Both bulbs flash at $t = 0$. Represent the flashes with points on your spacetime plot. Put in world lines representing travel of the light from each flash.</li>
#         <li>Suppose the James Webb Space Telescope is at rest at $x = 150000$ km. Mark it on the plot with the symbol of your choice, then plot its world line.</li>
#         <li>Aliens are sending a reconnaissance microprobe through the solar system at high speed. At $t = 0$, the probe is lurking at $x = 500000$ km. In the (approximate) rest frame of observers on Earth, the microprobe moves at speed $0.1c$ in the -x direction. Mark the probe's position at $t = 0$ and plot its world line.</li>
#         </ol></li>
# </ol>
#
# Based only on your plot, would you say the flashes were simultaneous the point of view of the James Webb Space Telescope? What about from the point of view of the microprobe?

# %%
#The flashes from the point of view of the telescope are simultaneous as the telescope is positioned at exactly half the 
#distance between the flashes and at rest, indicating that the light flashes will reach the telescope at the same point in
#spacetime, as seen below. In regards to the alien microprobe's point of view, it will see the blue flash (originating from
#x=300,000km) as this flash is signifcantly closer in spacetime to the probe, then see the red flash (originating from x=0km).
#The -x-direction velocity of the probe does result in it seeing the flashes sooner than if it was at rest as this velocity
#slopes the microprobe's worldline.

#2.A.

t = np.linspace(0, 200, num=201, endpoint=True)
fig, ax1 = plt.subplots(figsize=(7,7))# Make a figure

x0p=c*t#World lines for bulb at x=0 m
x0n=-c*t

x3p=c*t+(3e8)#World lines for bulb at x=300,000 km
x3n=-c*t+(3e8)

ax1.plot(x0p,c*t,'r')
ax1.plot(x0n,c*t,'r',label='Bulb @x=0 m')
ax1.plot(x3p,c*t,'b',label='Bulb @x=3e8 m')
ax1.plot(x3n,c*t,'b')

ax1.spines['left'].set_position(('data', 0))
ax1.spines['bottom'].set_position(('data', 0))
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.set_aspect('equal')

ax1.set_xlim([-2e8, 5.5e8])
ax1.set_ylim([-2e8, 5.5e8])

plt.legend()
ax1.text(5.6e8,0,'x');
ax1.text(0,5.6e8,'ct');
plt.show()

#2.B.

t = np.linspace(0, 200, num=201, endpoint=True)
fig, ax2 = plt.subplots(figsize=(7,7))# Make a figure

xJW=1.5e8*np.ones(len(t))

ax2.plot(x0p,c*t,'r')
ax2.plot(x0n,c*t,'r',label='Bulb @x=0 m')
ax2.plot(x3p,c*t,'b',label='Bulb @x=3e8 m')
ax2.plot(x3n,c*t,'b')
ax2.plot(xJW,c*t,'g',label='James Webb Space Telescope')

ax2.spines['left'].set_position(('data', 0))
ax2.spines['bottom'].set_position(('data', 0))
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.set_aspect('equal')

ax2.set_xlim([-2e8, 5.5e8])
ax2.set_ylim([-2e8, 5.5e8])

plt.legend()
ax2.text(5.6e8,0,'x');
ax2.text(0,5.6e8,'ct');
plt.show()

#2.C.

t = np.linspace(0, 200, num=201, endpoint=True)
fig, ax3 = plt.subplots(figsize=(7,7))# Make a figure

xA=-c*0.1*t+5e8

ax3.plot(x0p,c*t,'r')
ax3.plot(x0n,c*t,'r',label='Bulb @x=0 m')
ax3.plot(x3p,c*t,'b',label='Bulb @x=3e8 m')
ax3.plot(x3n,c*t,'b')
ax3.plot(xJW,c*t,'g',label='James Webb Space Telescope')
ax3.plot(xA,c*t,color='black',label='Alien Microprobe')

ax3.spines['left'].set_position(('data', 0))
ax3.spines['bottom'].set_position(('data', 0))
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.set_aspect('equal')

ax3.set_xlim([-2e8, 5.5e8])
ax3.set_ylim([-2e8, 5.5e8])

plt.legend()
ax3.text(5.6e8,0,'x');
ax3.text(0,5.6e8,'ct');
